# %%
import pandas as pd

# %%
evictiondata = pd.read_csv('tracts.csv')

# %%
dallascounty = evictiondata[evictiondata['parent-location'] == 'Dallas County, Texas']

# %%
tarrantcounty = evictiondata[evictiondata['parent-location'] == 'Tarrant County, Texas']

# %%
collincounty = evictiondata[evictiondata['parent-location'] == 'Collin County, Texas']

# %%
dentoncounty = evictiondata[evictiondata['parent-location'] == 'Denton County, Texas']

# %%
dallascounty[dallascounty['year']==2016]
# Out:
#              GEOID  year     name       parent-location  population  \
# 17611  48113000100  2016     1.00  Dallas County, Texas      3951.0
# 17628  48113000201  2016     2.01  Dallas County, Texas      2907.0
# 17645  48113000202  2016     2.02  Dallas County, Texas      3759.0
# 17662  48113000300  2016     3.00  Dallas County, Texas      4316.0
# 17679  48113000401  2016     4.01  Dallas County, Texas      6430.0
# 17696  48113000404  2016     4.04  Dallas County, Texas      3698.0
# 17713  48113000405  2016     4.05  Dallas County, Texas      2260.0
# 17730  48113000406  2016     4.06  Dallas County, Texas      7966.0
# 17747  48113000500  2016     5.00  Dallas County, Texas      4622.0
# 17764  48113000601  2016     6.01  Dallas County, Texas      6131.0
# 17781  48113000603  2016     6.03  Dallas County, Texas      4144.0
# 17798  48113000605  2016     6.05  Dallas County, Texas      2443.0
# 17815  48113000606  2016     6.06  Dallas County, Texas      2808.0
# ...

# %%
dallascounty
# Out:
#              GEOID  year     name       parent-location  population  \
# 17595  48113000100  2000     1.00  Dallas County, Texas     3900.72
# 17596  48113000100  2001     1.00  Dallas County, Texas     3900.72
# 17597  48113000100  2002     1.00  Dallas County, Texas     3900.72
# 17598  48113000100  2003     1.00  Dallas County, Texas     3900.72
# 17599  48113000100  2004     1.00  Dallas County, Texas     3900.72
# 17600  48113000100  2005     1.00  Dallas County, Texas     4291.00
# 17601  48113000100  2006     1.00  Dallas County, Texas     4291.00
# 17602  48113000100  2007     1.00  Dallas County, Texas     4291.00
# 17603  48113000100  2008     1.00  Dallas County, Texas     4291.00
# 17604  48113000100  2009     1.00  Dallas County, Texas     4291.00
# 17605  48113000100  2010     1.00  Dallas County, Texas     4009.00
# 17606  48113000100  2011     1.00  Dallas County, Texas     3951.00
# 17607  48113000100  2012     1.00  Dallas County, Texas     3951.00
# ...

# %%
dallascounty[['GEOID', 'eviction-rate']].groupby('GEOID').mean()
# Out:
#              eviction-rate
# GEOID
# 48113000100       1.498824
# 48113000201       0.677647
# 48113000202       1.062353
# 48113000300       0.690588
# 48113000401       1.996471
# 48113000404       1.951765
# 48113000405       5.871765
# 48113000406       2.345882
# 48113000500       3.455294
# 48113000601       3.052353
# 48113000603       3.038824
# 48113000605       2.202353
# 48113000606       1.837059
# 48113000701       0.785882
# 48113000702       0.727647
# 48113000800       3.384706
# 48113000900       2.202353
# 48113001001       1.125294
# 48113001002       1.454118
# 48113001101       2.252941
# 48113001102       0.887647
# 48113001202       3.004118
# 48113001203       2.130000
# 48113001204       2.164118
# 48113001301       1.152941
# 48113001302       4.191176
# 48113001400       9.018235
# 48113001502       6.772353
# 48113001503       6.675294
# 48113001504       8.935882
# ...                    ...
# 48113019100       1.795294
# 48113019202       2.121765
# ...
